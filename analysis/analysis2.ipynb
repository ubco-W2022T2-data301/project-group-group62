# %% [markdown]
# # Ximin Xu

# %% [markdown]
# ## Research question/interests
#
# **According to EDA, I have found that there is some connections among the price, the location and the rating. However, I still want to know what is the connection, I want to produce an ultimate guide for tourists and house hosts. In which range of price and location people like the most and in which range of them people are not interested in.**
#
# This would help me to understand what renter's demands in HongKong's airbnb are, and figure out which part in Hong Kong is the most popular position.
#
# In order to accomplish this, I will remain the following column: review_scores_communication, review_scores_location,review_scores_value,review_scores rating, review_score_accuracy,neighbourhood_cleansed, price per accomodate and average rating.
#
# I need to combine the three columns (rating, price, location) into one plot and compare. I can also apply it to the map of Hong Kong for a further explanation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('../data/raw/listings.csv')
dataset
# Out:
#           id                          listing_url       scrape_id  \
# 0      17891   https://www.airbnb.com/rooms/17891  20221223064914
# 1      72571   https://www.airbnb.com/rooms/72571  20221223064914
# 2     923017  https://www.airbnb.com/rooms/923017  20221223064914
# 3     944283  https://www.airbnb.com/rooms/944283  20221223064914
# 4     956857  https://www.airbnb.com/rooms/956857  20221223064914
# ...      ...                                  ...             ...
# 5189  869969  https://www.airbnb.com/rooms/869969  20221223064914
# 5190  870046  https://www.airbnb.com/rooms/870046  20221223064914
# 5191  894221  https://www.airbnb.com/rooms/894221  20221223064914
# 5192  894224  https://www.airbnb.com/rooms/894224  20221223064914
# 5193  903169  https://www.airbnb.com/rooms/903169  20221223064914
#
#      last_scraped           source  \
# 0      2022-12-23  previous scrape
# 1      2022-12-23      city scrape
# 2      2022-12-23      city scrape
# ...
